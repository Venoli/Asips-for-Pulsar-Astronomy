# %%
# %matplotlib notebook

# %%
# %load_ext autoreload

# %autoreload 2

# %%
from asips.asips_delayed_progressive import Asips
asips = Asips()
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  \
# 301                      118.851562
# 302                      101.023438
# 303                      107.070312
# 304                      131.945312
# 305                      127.093750
#
#      Standard deviation of the integrated profile  \
# 301                                     39.905374
# 302                                     52.064333
# 303                                     47.729247
# 304                                     48.760145
# 305                                     54.602031
#
#      Excess kurtosis of the integrated profile  \
# 301                                   0.342266
# 302                                   0.296000
# 303                                   0.546229
# 304                                  -0.170860
# 305                                   0.004681
#
#      Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 301                            0.408057                  1.811873
# 302                           -0.108197                  1.803512
# 303                            0.430071                  3.990803
# 304                           -0.286805                  2.846154
# 305                           -0.544766                  2.206522
#
#      Standard deviation of the DM-SNR curve  \
# 301                               15.281218
# 302                               12.259896
# 303                               25.756463
# 304                               17.445608
# 305                               14.110410
#
#      Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 301                            10.218044                    120.638361
# 302                            11.113283                    174.258560
# 303                             7.122971                     52.715586
# 304                             8.064323                     78.326687
# 305                             9.767350                    123.607601
#
#      target_class
# 301             0
# 302             0
# 303             0
# 304             0
# 305             0
# -------INIT STREAMS-------

# %%
#Pretrain
asips.pretrain()
# Out:
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.188951
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 300
# "Time difference: 0:00:00.188951 \ninfo: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,\n                                    leaf_prediction='nba',\n                                    max_byte_size=33554432,\n                                    memory_estimate_period=1000000,\n                                    min_samples_reevaluate=20, nb_threshold=0,\n                                    nominal_attributes=None,\n                                    split_confidence=1e-07,\n                                    split_criterion='gaussian_hellinger',\n                                    stop_mem_management=False,\n                                    tie_threshold=0.05)> \n Number of learning samples: 300"

# %%
#First batch
asips.make_prediction(asips.stream_first)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]{'name': '-MYe7iXkayGGDf1_9nR9'}
#  #########----------- [45%] [1.29s]{'name': '-MYe7iprN1wuq7PnrME1'}
#  ##########---------- [50%] [2.50s]{'name': '-MYe7j82B2P9udrr52_v'}
#  ################---- [80%] [3.66s]{'name': '-MYe7jg3dj_syjfT44HY'}
#  #################### [99%] [5.99s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9700
# M0 - Kappa        : 0.5562
# 17
# M0 - Precision: 0.6667
# M0 - Recall: 0.5000
# M0 - F1 score: 0.5714
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.02
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# 17
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.7071067811865476
# Recall: 0.95
# Precision: 0.5
# F1 Score: 1.0
# 'Kappa: 0.6428571428571426 \nG-Mean: 0.6428571428571426 \nAccuracy: 0.7071067811865476 \nRecall: 0.95 \nPrecision: 0.5 \nF1 Score: 1.0'

# %%
asips.make_prediction(asips.stream_second)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.01s]{'name': '-MY_XLpxzQgOSi_UZAq4'}
# {'name': '-MY_XM8Ih0MoBroz4KV2'}
#  ####---------------- [20%] [2.64s]{'name': '-MY_XMRPqMDYrHe1zQ_a'}
#  ######-------------- [30%] [3.77s]{'name': '-MY_XMiEixEaLKMUv1q6'}
#  #######------------- [35%] [4.99s]{'name': '-MY_XN0UZr5tiNT5TIIn'}
#  ##########---------- [50%] [6.22s]{'name': '-MY_XNJg1GAlyqREN24X'}
#  #############------- [65%] [7.45s]{'name': '-MY_XNc2YjlrONZq6YS_'}
#  ##############------ [70%] [8.67s]{'name': '-MY_XNunJzNZuNhA62sp'}
# {'name': '-MY_XODAdP6wGuiDyaxw'}
#  ###################- [95%] [11.13s]{'name': '-MY_XOWGkWMSEwc81D72'}
#  #################### [99%] [12.27s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# 11
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.03
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# 11
# Kappa: 1.0
# G-Mean: 1.0
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0

# %%
asips.make_prediction(asips.stream_second)
# Out:
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]{'name': '-MYTjrUE4s6S1s5MZm3S'}
# {'name': '-MYTjrmK54_YECcc_tmB'}
#  ####---------------- [20%] [2.55s]{'name': '-MYTjs4R5zGrlJGXJJTJ'}
#  ######-------------- [30%] [3.69s]{'name': '-MYTjsMEmoQUWmiguwI9'}
#  #######------------- [35%] [4.84s]{'name': '-MYTjsc55hWYoW1aWxf-'}
#  ##########---------- [50%] [5.91s]{'name': '-MYTjsuN0DneBxk00kBt'}
#  #############------- [65%] [7.16s]{'name': '-MYTjtBeCnfZ_OOVLOF8'}
#  ##############------ [70%] [8.25s]{'name': '-MYTjtUI03fJrZBaUMhm'}
# {'name': '-MYTjtmAfeVm5J8TuQB2'}
#  ###################- [95%] [10.75s]{'name': '-MYTju4Zf5lelJ-3Q9gu'}
#  #################### [99%] [11.97s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.03
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0
# Specificity(TNR): 1.0
# G-Mean: 1.0

# %%
# from asips_delayed_progressive import Asips
# asips = Asips()
asips.learn('-MYXVO10LSS4_ZWaKpKR')
# Out:
# {'excessKurtosisOfTheDMSNRCurve': 4.652341839, 'excessKurtosisOfTheIntegratedProfile': 2.478374846, 'meanOfTheDMSNRCurve': 8.230769231, 'meanOfTheIntegratedProfile': 52.3359375, 'skewnessOfTheDMSNRCurve': 21.98788225, 'skewnessOfTheIntegratedProfile': 10.17917088, 'standardDeviationOfTheDMSNRCurve': 34.77594683, 'standardDeviationOfTheIntegratedProfile': 34.77500839, 'targetClass': 1, 'yPred': 1}
# {"excessKurtosisOfTheDMSNRCurve": 4.652341839, "excessKurtosisOfTheIntegratedProfile": 2.478374846, "meanOfTheDMSNRCurve": 8.230769231, "meanOfTheIntegratedProfile": 52.3359375, "skewnessOfTheDMSNRCurve": 21.98788225, "skewnessOfTheIntegratedProfile": 10.17917088, "standardDeviationOfTheDMSNRCurve": 34.77594683, "standardDeviationOfTheIntegratedProfile": 34.77500839, "targetClass": 1, "yPred": 1}
# jjjj
#    Mean of the integrated profile  \
# 0                        4.652342
#
#    Standard deviation of the integrated profile  \
# 0                                      2.478375
#
#    Excess kurtosis of the integrated profile  \
# 0                                   8.230769
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           52.335938                 21.987882
#
#    Standard deviation of the DM-SNR curve  \
# 0                               10.179171
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                            34.775947                     34.775008
#
#    target_class  y_pred
# 0             1       1
#    Mean of the integrated profile  \
# 0                        4.652342
#
#    Standard deviation of the integrated profile  \
# 0                                      2.478375
#
#    Excess kurtosis of the integrated profile  \
# 0                                   8.230769
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           52.335938                 21.987882
#
#    Standard deviation of the DM-SNR curve  \
# 0                               10.179171
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                            34.775947                     34.775008
#
#    target_class
# 0             1
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 0:00:00.004928 Time difference
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>

# %%
asips.learn_from_all()
# Out:
# {"-MYXVFtx5uXnSuyIaf0d": {"excessKurtosisOfTheDMSNRCurve": 2.2292447280000003, "excessKurtosisOfTheIntegratedProfile": 3.6477399239999997, "meanOfTheDMSNRCurve": 33.86036789, "meanOfTheIntegratedProfile": 50.9296875, "skewnessOfTheDMSNRCurve": 4.419700221, "skewnessOfTheIntegratedProfile": 17.38148313, "standardDeviationOfTheDMSNRCurve": 57.92865293, "standardDeviationOfTheIntegratedProfile": 32.59413856, "targetClass": 1, "yPred": 1}, "-MYXVGCLwILdLbHJ-6OW": {"excessKurtosisOfTheDMSNRCurve": 8.359921014, "excessKurtosisOfTheIntegratedProfile": 0.53599405, "meanOfTheDMSNRCurve": 2.8979933110000005, "meanOfTheIntegratedProfile": 95.6640625, "skewnessOfTheDMSNRCurve": 88.1807417, "skewnessOfTheIntegratedProfile": 0.535184976, "standardDeviationOfTheDMSNRCurve": 16.51930955, "standardDeviationOfTheIntegratedProfile": 47.60650516, "targetClass": 0, "yPred": 0}, "-MYXVGVT3hYLGCvRGqNm": {"excessKurtosisOfTheDMSNRCurve": 5.018115302, "excessKurtosisOfTheIntegratedProfile": 1.391329691, "meanOfTheDMSNRCurve": 8.022575251000001, "meanOfTheIntegratedProfile": 72.5859375, "skewnessOfTheDMSNRCurve": 25.03925564, "skewnessOfTheIntegratedProfile": 4.420335099999999, "standardDeviationOfTheDMSNRCurve": 37.46327511, "standardDeviationOfTheIntegratedProfile": 39.65663708, "targetClass": 0, "yPred": 1}, "-MYXVGnrP5N1O3jVqr_y": {"excessKurtosisOfTheDMSNRCurve": 0.295248594, "excessKurtosisOfTheIntegratedProfile": 6.187429415, "meanOfTheDMSNRCurve": 121.367893, "meanOfTheIntegratedProfile": 6.4140625, "skewnessOfTheDMSNRCurve": -1.027613812, "skewnessOfTheIntegratedProfile": 40.10131647, "standardDeviationOfTheDMSNRCurve": 61.4164204, "standardDeviationOfTheIntegratedProfile": 30.92014092, "targetClass": 1, "yPred": 1}, "-MYXVOIVGf7NFxEw7nMf": {"excessKurtosisOfTheDMSNRCurve": 1.389508736, "excessKurtosisOfTheIntegratedProfile": 1.118794002, "
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# 0:00:00.012570 Time difference
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>

# %%
asips.learn_from_all()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ee2cac244980> in <module>
# ----> 1 asips.learn_from_all()
#
# ~/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips_delayed_progressive.py in learn_from_all(self)
#     132         # convert to a dataframe
#     133         dataframe = pd.DataFrame.from_dict(j, orient='columns')
# --> 134         dataframe.columns = asips_utils.DATAFRAME_HEAD
#     135         print(dataframe)
#     136
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 10 elements

# %%
# !python flask_api.py
# Out:
#  * Serving Flask app "flask_api" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (50, 9),(4350, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------STREAMS STARTING-------
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# 300 samples analyzed.
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# -------PRETRAIN FINISHED-------
# <_MainProcess name='MainProcess' parent=None started>
# {'name': '-MYGiw02oDHf82eifLws'}
# {'name': '-MYGiwJ09NZQtuwdZ7JX'}
# {'name': '-MYGiw_vaIVB0Iw1WmtL'}
# 50 samples analyzed.
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0
# Specificity(TNR): 1.0
# G-Mean: 1.0
# {'name': '-MYGiwsxaPQ66CZ0vGj6'}
# 127.0.0.1 - - [15/Apr/2021 00:24:09] "GET / HTTP/1.1" 200 -
# ^C

# %% [markdown]
# ### API Testing

# %%
cd asips
# Out:
# /Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips

# %%
from asips.asips_delayed_progressive import Asips
asips = Asips()
asips.x()
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  \
# 301                      118.851562
# 302                      101.023438
# 303                      107.070312
# 304                      131.945312
# 305                      127.093750
#
#      Standard deviation of the integrated profile  \
# 301                                     39.905374
# 302                                     52.064333
# 303                                     47.729247
# 304                                     48.760145
# 305                                     54.602031
#
#      Excess kurtosis of the integrated profile  \
# 301                                   0.342266
# 302                                   0.296000
# 303                                   0.546229
# 304                                  -0.170860
# 305                                   0.004681
#
#      Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 301                            0.408057                  1.811873
# 302                           -0.108197                  1.803512
# 303                            0.430071                  3.990803
# 304                           -0.286805                  2.846154
# 305                           -0.544766                  2.206522
#
#      Standard deviation of the DM-SNR curve  \
# 301                               15.281218
# 302                               12.259896
# 303                               25.756463
# 304                               17.445608
# 305                               14.110410
#
#      Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 301                            10.218044                    120.638361
# 302                            11.113283                    174.258560
# 303                             7.122971                     52.715586
# 304                             8.064323                     78.326687
# 305                             9.767350                    123.607601
#
#      target_class
# 301             0
# 302             0
# 303             0
# 304             0
# 305             0
# -------INIT STREAMS-------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-f0252ddb6e76> in <module>
#       1 from asips.asips_delayed_progressive import Asips
#       2 asips = Asips()
# ----> 3 asips.x()
#
# AttributeError: 'Asips' object has no attribute 'x'

# %%
from test_with_other_classifiers import TestWithOtherClassifiers
test_other = TestWithOtherClassifiers()
log = test_other.classification_pipeline('under_over_bagging')
# Out:
#    Mean of the integrated profile  \
# 0                      121.156250
# 1                       76.968750
# 2                      130.585938
# 3                       84.804688
# 4                      109.406250
#
#    Standard deviation of the integrated profile  \
# 0                                     48.372971
# 1                                     36.175557
# 2                                     53.229534
# 3                                     36.117659
# 4                                     55.912521
#
#    Excess kurtosis of the integrated profile  \
# 0                                   0.375485
# 1                                   0.712898
# 2                                   0.133408
# 3                                   0.825013
# 4                                   0.565106
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.013165                  3.168896
# 1                            3.388719                  2.399666
# 2                           -0.297242                  2.743311
# 3                            3.274125                  2.790134
# 4                            0.056247                  2.797659
#
#    Standard deviation of the DM-SNR curve  \
# 0                               18.399367
# 1                               17.570997
# 2                               22.362553
# 3                               20.618009
# 4                               19.496527
#
#    Excess kurtosis of the DM-SNR curve  Skewness of the DM-SNR curve  \
# 0                             7.449874                     65.159298
# 1                             9.414652                    102.722975
# 2                             8.508364                     74.031324
# 3                             8.405008                     76.291128
# 4                             9.443282                     97.374578
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# 333333333333
# {"-MYlvuN95ddxj0Tly3FR": {"excessKurtosisOfTheDMSNRCurve": 7.247670151, "excessKurtosisOfTheIntegratedProfile": 0.7442031720000001, "meanOfTheDMSNRCurve": 3.22826087, "meanOfTheIntegratedProfile": 76.8515625, "skewnessOfTheDMSNRCurve": 56.44359608, "skewnessOfTheIntegratedProfile": 1.4641748069999998, "smoteBagging": 1, "standardDeviationOfTheDMSNRCurve": 21.03621429, "standardDeviationOfTheIntegratedProfile": 41.49982866, "targetClass": 0, "yPred": 0}, "-MYlvuNA6QWJ2j4ZA897": {"excessKurtosisOfTheDMSNRCurve": -0.713518139, "excessKurtosisOfTheIntegratedProfile": -0.111229859, "meanOfTheDMSNRCurve": 117.37792639999999, "meanOfTheIntegratedProfile": 135.2734375, "skewnessOfTheDMSNRCurve": -1.3532475480000001, "skewnessOfTheIntegratedProfile": 0.462083597, "smoteBagging": 1, "standardDeviationOfTheDMSNRCurve": 80.49672908, "standardDeviationOfTheIntegratedProfile": 41.95583892, "targetClass": 0, "yPred": 1}, "-MYlvuNA6QWJ2j4ZA898": {"excessKurtosisOfTheDMSNRCurve": 5.018115302, "excessKurtosisOfTheIntegratedProfile": 1.391329691, "meanOfTheDMSNRCurve": 8.022575251000001, "meanOfTheIntegratedProfile": 72.5859375, "skewnessOfTheDMSNRCurve": 25.03925564, "skewnessOfTheIntegratedProfile": 4.420335099999999, "smoteBagging": 1, "standardDeviationOfTheDMSNRCurve": 37.46327511, "standardDeviationOfTheIntegratedProfile": 39.65663708, "targetClass": 0, "yPred": 1}, "-MYlvuNJoUqTeBtCDzoF": {"excessKurtosisOfTheDMSNRCurve": 2.
 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}, '-MYlvyY0U2WFmZcng7dt': {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}, '-MYlvyY1FJDX13CRBkNo': {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'sta ...
# 444444444
# -MYlvuN95ddxj0Tly3FR
# {'excessKurtosisOfTheDMSNRCurve': 7.247670151, 'excessKurtosisOfTheIntegratedProfile': 0.7442031720000001, 'meanOfTheDMSNRCurve': 3.22826087, 'meanOfTheIntegratedProfile': 76.8515625, 'skewnessOfTheDMSNRCurve': 56.44359608, 'skewnessOfTheIntegratedProfile': 1.4641748069999998, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 21.03621429, 'standardDeviationOfTheIntegratedProfile': 41.49982866, 'targetClass': 0, 'yPred': 0}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.464175           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               21.036214
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.499829           0.0     0.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.464175                               21.036214
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.499829             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNA6QWJ2j4ZA897
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNA6QWJ2j4ZA898
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvuNJoUqTeBtCDzoF
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvuNJoUqTeBtCDzoG
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvugo5OEmmvWytJia
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvugpP0F5lfjcPz4d
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyY0U2WFmZcng7dt
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyY1FJDX13CRBkNo
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyY41kboGn3UKIx4
# {'excessKurtosisOfTheDMSNRCurve': 7.247670151, 'excessKurtosisOfTheIntegratedProfile': 0.7442031720000001, 'meanOfTheDMSNRCurve': 3.22826087, 'meanOfTheIntegratedProfile': 76.8515625, 'skewnessOfTheDMSNRCurve': 56.44359608, 'skewnessOfTheIntegratedProfile': 1.4641748069999998, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 21.03621429, 'standardDeviationOfTheIntegratedProfile': 41.49982866, 'targetClass': 0, 'yPred': 0}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.464175           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               21.036214
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.499829           0.0     0.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.464175                               21.036214
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.499829             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyYEygDGeb_XGkg1
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlvyYFq5EL7ACvbkWP
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyqFbMLkHDp-_KTh
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlvyqFbMLkHDp-_KTi
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0fVY6526X42rlme
# {'excessKurtosisOfTheDMSNRCurve': 5.018115302, 'excessKurtosisOfTheIntegratedProfile': 1.391329691, 'meanOfTheDMSNRCurve': 8.022575251000001, 'meanOfTheIntegratedProfile': 72.5859375, 'skewnessOfTheDMSNRCurve': 25.03925564, 'skewnessOfTheIntegratedProfile': 4.420335099999999, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 37.46327511, 'standardDeviationOfTheIntegratedProfile': 39.65663708, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            4.420335           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               37.463275
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     39.656637           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             5.018115
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    1.39133                  8.022575
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       72.585938                     25.039256
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            4.420335                               37.463275
#
#    Standard deviation of the integrated profile  target_class
# 0                                     39.656637             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fVY6526X42rlmf
# {'excessKurtosisOfTheDMSNRCurve': 7.247670151, 'excessKurtosisOfTheIntegratedProfile': 0.7442031720000001, 'meanOfTheDMSNRCurve': 3.22826087, 'meanOfTheIntegratedProfile': 76.8515625, 'skewnessOfTheDMSNRCurve': 56.44359608, 'skewnessOfTheIntegratedProfile': 1.4641748069999998, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 21.03621429, 'standardDeviationOfTheIntegratedProfile': 41.49982866, 'targetClass': 0, 'yPred': 0}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.464175           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               21.036214
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.499829           0.0     0.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                              7.24767
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.744203                  3.228261
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       76.851562                     56.443596
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.464175                               21.036214
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.499829             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fVY6526X42rlmg
# {'excessKurtosisOfTheDMSNRCurve': -0.615911193, 'excessKurtosisOfTheIntegratedProfile': 0.083238873, 'meanOfTheDMSNRCurve': 126.7299331, 'meanOfTheIntegratedProfile': 130.8359375, 'skewnessOfTheDMSNRCurve': -1.265235268, 'skewnessOfTheIntegratedProfile': -0.49444035, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 83.43642448, 'standardDeviationOfTheIntegratedProfile': 53.38199271, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            -0.49444           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               83.436424
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     53.381993           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.615911
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   0.083239                126.729933
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      130.835938                     -1.265235
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            -0.49444                               83.436424
#
#    Standard deviation of the integrated profile  target_class
# 0                                     53.381993             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0feWf81tS-Yah89
# {'excessKurtosisOfTheDMSNRCurve': -0.713518139, 'excessKurtosisOfTheIntegratedProfile': -0.111229859, 'meanOfTheDMSNRCurve': 117.37792639999999, 'meanOfTheIntegratedProfile': 135.2734375, 'skewnessOfTheDMSNRCurve': -1.3532475480000001, 'skewnessOfTheIntegratedProfile': 0.462083597, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 80.49672908, 'standardDeviationOfTheIntegratedProfile': 41.95583892, 'targetClass': 0, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            0.462084           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               80.496729
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     41.955839           0.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                            -0.713518
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   -0.11123                117.377926
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                      135.273438                     -1.353248
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            0.462084                               80.496729
#
#    Standard deviation of the integrated profile  target_class
# 0                                     41.955839             0
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0]
# 444444444
# -MYlw0fh1GESmMkX-q5J
# {'excessKurtosisOfTheDMSNRCurve': 2.2292447280000003, 'excessKurtosisOfTheIntegratedProfile': 3.6477399239999997, 'meanOfTheDMSNRCurve': 33.86036789, 'meanOfTheIntegratedProfile': 50.9296875, 'skewnessOfTheDMSNRCurve': 4.419700221, 'skewnessOfTheIntegratedProfile': 17.38148313, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 57.92865293, 'standardDeviationOfTheIntegratedProfile': 32.59413856, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           17.381483           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               57.928653
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     32.594139           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             2.229245
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                    3.64774                 33.860368
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       50.929688                        4.4197
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           17.381483                               57.928653
#
#    Standard deviation of the integrated profile  target_class
# 0                                     32.594139             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0yQF_Qra_ja-Ztw
# {'excessKurtosisOfTheDMSNRCurve': 1.3950157980000002, 'excessKurtosisOfTheIntegratedProfile': 1.4097378459999999, 'meanOfTheDMSNRCurve': 42.98829431, 'meanOfTheIntegratedProfile': 92.890625, 'skewnessOfTheDMSNRCurve': 0.321894692, 'skewnessOfTheIntegratedProfile': 1.964645676, 'smoteBagging': 0, 'standardDeviationOfTheDMSNRCurve': 74.76461298, 'standardDeviationOfTheIntegratedProfile': 50.00066162, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                            1.964646           0.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                               74.764613
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     50.000662           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             1.395016
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   1.409738                 42.988294
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                       92.890625                      0.321895
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                            1.964646                               74.764613
#
#    Standard deviation of the integrated profile  target_class
# 0                                     50.000662             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]
# 444444444
# -MYlw0y_6m7ZcJ26a6_M
# {'excessKurtosisOfTheDMSNRCurve': 0.295248594, 'excessKurtosisOfTheIntegratedProfile': 6.187429415, 'meanOfTheDMSNRCurve': 121.367893, 'meanOfTheIntegratedProfile': 6.4140625, 'skewnessOfTheDMSNRCurve': -1.027613812, 'skewnessOfTheIntegratedProfile': 40.10131647, 'smoteBagging': 1, 'standardDeviationOfTheDMSNRCurve': 61.4164204, 'standardDeviationOfTheIntegratedProfile': 30.92014092, 'targetClass': 1, 'yPred': 1}
# 11111111111
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  smoteBagging  \
# 0                           40.101316           1.0
#
#    Standard deviation of the DM-SNR curve  \
# 0                                61.41642
#
#    Standard deviation of the integrated profile  target_class  y_pred
# 0                                     30.920141           1.0     1.0
#    Excess kurtosis of the DM-SNR curve  \
# 0                             0.295249
#
#    Excess kurtosis of the integrated profile  Mean of the DM-SNR curve  \
# 0                                   6.187429                121.367893
#
#    Mean of the integrated profile  Skewness of the DM-SNR curve  \
# 0                        6.414062                     -1.027614
#
#    Skewness of the integrated profile  Standard deviation of the DM-SNR curve  \
# 0                           40.101316                                61.41642
#
#    Standard deviation of the integrated profile  target_class
# 0                                     30.920141             1
# Features:
# ['Excess kurtosis of the DM-SNR curve', 'Excess kurtosis of the integrated profile', 'Mean of the DM-SNR curve', 'Mean of the integrated profile', 'Skewness of the DM-SNR curve', 'Skewness of the integrated profile', 'Standard deviation of the DM-SNR curve', 'Standard deviation of the integrated profile']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [1]

# %%
# !python flask_api.py
# Out:
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#  * Serving Flask app "flask_api" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with fsevents reloader
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#  * Debugger is active!
#  * Debugger PIN: 159-978-075
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# <class 'datetime.timedelta'>
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.692775
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 500
#  Features: ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Target values: [0, 1]
# 127.0.0.1 - - [21/Apr/2021 11:49:46] "GET /pretrain/500 HTTP/1.1" 200 -
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  ##------------------ [10%] [0.00s]None
#  #####--------------- [25%] [0.00s]None
#  ######-------------- [30%] [0.00s]None
#  #########----------- [45%] [0.01s]None
#  ##########---------- [50%] [0.01s]None
#  ###########--------- [55%] [0.01s]None
#  ############-------- [60%] [0.01s]None
#  #############------- [65%] [0.01s]None
#  ################---- [80%] [0.01s]None
#  ###################- [95%] [0.01s]None
#  #################### [99%] [0.01s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9500
# M0 - Kappa        : 0.7340
# M0 - Precision: 0.8000
# M0 - Recall: 0.7273
# M0 - F1 score: 0.7619
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9500
# M0 - Kappa        : 0.7340
# M0 - Precision: 0.8000
# M0 - Recall: 0.7273
# M0 - F1 score: 0.7619
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 1.0
# G-Mean: 1.0
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1 Score: 1.0
# 127.0.0.1 - - [21/Apr/2021 11:49:59] "GET /predict/100 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]None
#  ####---------------- [20%] [0.00s]None
# None
#  #####--------------- [25%] [0.01s]None
#  #######------------- [35%] [0.02s]None
#  ###########--------- [55%] [0.02s]None
#  #############------- [65%] [0.02s]None
#  ##############------ [70%] [0.02s]None
#  ###################- [95%] [0.02s]None
#  #################### [99%] [0.02s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9400
# M0 - Kappa        : 0.6670
# M0 - Precision: 0.7778
# M0 - Recall: 0.6364
# M0 - F1 score: 0.7000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.00
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9400
# M0 - Kappa        : 0.6670
# M0 - Precision: 0.7778
# M0 - Recall: 0.6364
# M0 - F1 score: 0.7000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.00
# M0 - Total time    (s)  : 0.00
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.7071067811865476
# Recall: 0.95
# Precision: 0.5
# F1 Score: 1.0
# 127.0.0.1 - - [21/Apr/2021 11:50:16] "GET /predict/100 HTTP/1.1" 200 -
#                       excessKurtosisOfTheDMSNRCurve  ...  yPred
# -MYn4RmcpzL5yoKyIKdR                      10.849845  ...      1
# -MYn4RmfYu90gn2yxhhS                       2.840049  ...      1
# -MYn4Rmp1WQwg9U3A94L                       0.263897  ...      1
# -MYn4Rn-Jw9Xew3F3Jt2                       4.989841  ...      1
# -MYn4RnI4qsKAcY9TBnK                       2.694902  ...      1
# -MYn4S5e3Pa1VlSSPYiw                       3.136580  ...      1
# -MYn4S5oBmbV0xjbTzf4                       0.974168  ...      1
# -MYn4S5yPQ1OduD_jtWb                       1.506916  ...      1
# -MYn4S66yXptAKnT0GRC                       1.304086  ...      1
# -MYn4S67X-jEIeVfOeB6                       0.871271  ...      1
# -MYn4VuGLl-nJQiUFSzk                       6.608766  ...      1
# -MYn4VuXo87TmSN9yqcr                       5.141095  ...      1
# -MYn4VuYniMX_2f2Dcdk                      13.379985  ...      1
# -MYn4VuYniMX_2f2Dcdl                       3.623148  ...      1
# -MYn4Vuh1SfenmLEQznG                       1.142133  ...      1
# -MYn4WDNyYwUWu3kDnVb                       3.882441  ...      1
# -MYn4WDOm3q4_CnAlQwB                       0.084836  ...      1
# -MYn4WDXCz5_qzi1KJBc                       5.862879  ...      1
# -MYn4WD_hcVlrGYoAYDQ                       0.273448  ...      1
#
# [19 rows x 10 columns]
#                       Excess kurtosis of the DM-SNR curve  ...  y_pred
# -MYn4RmcpzL5yoKyIKdR                            10.849845  ...       1
# -MYn4RmfYu90gn2yxhhS                             2.840049  ...       1
# -MYn4Rmp1WQwg9U3A94L                             0.263897  ...       1
# -MYn4Rn-Jw9Xew3F3Jt2                             4.989841  ...       1
# -MYn4RnI4qsKAcY9TBnK                             2.694902  ...       1
# -MYn4S5e3Pa1VlSSPYiw                             3.136580  ...       1
# -MYn4S5oBmbV0xjbTzf4                             0.974168  ...       1
# -MYn4S5yPQ1OduD_jtWb                             1.506916  ...       1
# -MYn4S66yXptAKnT0GRC                             1.304086  ...       1
# -MYn4S67X-jEIeVfOeB6                             0.871271  ...       1
# -MYn4VuGLl-nJQiUFSzk                             6.608766  ...       1
# -MYn4VuXo87TmSN9yqcr                             5.141095  ...       1
# -MYn4VuYniMX_2f2Dcdk                            13.379985  ...       1
# -MYn4VuYniMX_2f2Dcdl                             3.623148  ...       1
# -MYn4Vuh1SfenmLEQznG                             1.142133  ...       1
# -MYn4WDNyYwUWu3kDnVb                             3.882441  ...       1
# -MYn4WDOm3q4_CnAlQwB                             0.084836  ...       1
# -MYn4WDXCz5_qzi1KJBc                             5.862879  ...       1
# -MYn4WD_hcVlrGYoAYDQ                             0.273448  ...       1
#
# [19 rows x 10 columns]
#                       Mean of the integrated profile  ...  target_class
# -MYn4RmcpzL5yoKyIKdR                       73.015625  ...             0
# -MYn4RmfYu90gn2yxhhS                       60.929688  ...             1
# -MYn4Rmp1WQwg9U3A94L                       43.671875  ...             1
# -MYn4Rn-Jw9Xew3F3Jt2                       79.726562  ...             1
# -MYn4RnI4qsKAcY9TBnK                       55.460938  ...             1
#
# [5 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# Time difference: 0:00:00.038362
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Number of learning samples: 19
# 127.0.0.1 - - [21/Apr/2021 11:50:24] "GET /learn-from-all HTTP/1.1" 200 -
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# <class 'datetime.timedelta'>
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:05.450456
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 1000
#  Features: ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Target values: [0, 1]
# 127.0.0.1 - - [21/Apr/2021 11:50:52] "GET /pretrain/1000 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]None
#  #------------------- [5%] [0.00s]None
#  ##------------------ [10%] [0.00s]None
#  ###----------------- [14%] [0.00s]None
#  ####---------------- [19%] [0.00s]None
# None
#  #######------------- [33%] [0.01s]None
#  ########------------ [38%] [0.01s]None
#  ############-------- [62%] [0.01s]None
#  #############------- [67%] [0.01s]None
#  ##############------ [71%] [0.02s]None
#  ###############----- [76%] [0.02s]None
# None
#  ##################-- [90%] [0.02s]None
#  #################### [100%] [0.02s]
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9619
# M0 - Kappa        : 0.6939
# M0 - Precision: 0.7143
# M0 - Recall: 0.7143
# M0 - F1 score: 0.7143
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9619
# M0 - Kappa        : 0.6939
# M0 - Precision: 0.7143
# M0 - Recall: 0.7143
# M0 - F1 score: 0.7143
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.6428571428571426
# G-Mean: 0.6428571428571426
# Accuracy: 0.7071067811865476
# Recall: 0.95
# Precision: 0.5
# F1 Score: 1.0
# 127.0.0.1 - - [21/Apr/2021 11:51:06] "GET /predict/1000 HTTP/1.1" 200 -
#  * Detected change in '/Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/skmultiflow/evaluation/evaluate_prequential.py', reloading
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 212, in __init__
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 212, in __init__
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 118, in start
#     self._repopulate_pool()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 303, in _repopulate_pool
#     self._repopulate_pool()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 303, in _repopulate_pool
#     assert not _current_process._config.get('daemon'), \
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 326, in _repopulate_pool_static
# AssertionError: daemonic processes are not allowed to have children
#     w.start()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 118, in start
#     assert not _current_process._config.get('daemon'), \
# AssertionError: daemonic processes are not allowed to have children
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 118, in start
#     assert not _current_process._config.get('daemon'), \
# AssertionError: daemonic processes are not allowed to have children
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 303, in _repopulate_pool
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 212, in __init__
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 118, in start
#     assert not _current_process._config.get('daemon'), \
# AssertionError: daemonic processes are not allowed to have children
#     self._repopulate_pool()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/multiprocessing/process.py", line 118, in start
#     assert not _current_process._config.get('daemon'), \
# AssertionError: daemonic processes are not allowed to have children
#  * Restarting with fsevents reloader
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
#  * Debugger is active!
#  * Debugger PIN: 159-978-075
# -------PRETRAIN STARTED-------
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# <class 'datetime.timedelta'>
# -------PRETRAIN FINISHED-------
# Time difference: 0:00:00.397178
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
#  Number of learning samples: 400
#  Features: ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Target values: [0, 1]
# 127.0.0.1 - - [21/Apr/2021 12:00:10] "GET /pretrain/400 HTTP/1.1" 200 -
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# -------READ CSV-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]     Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]     Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
#
#
# -------INIT STREAMS-------
# -------INIT STREAMS-------
# -------INIT STREAMS-------
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
# Shape of new partitioned dataframes - (300, 9) , (100, 9),(100, 9)
#      Mean of the integrated profile  ...  target_class
# 301                      118.851562  ...             0
# 302                      101.023438  ...             0
# 303                      107.070312  ...             0
# 304                      131.945312  ...             0
# 305                      127.093750  ...             0
#
# [5 rows x 9 columns]
# -------INIT STREAMS-------
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]None
# None
#  ##------------------ [10%] [0.00s]None
#  ###----------------- [14%] [0.00s]None
# None
#  ####---------------- [19%] [0.00s]None
#  ######-------------- [29%] [0.01s]None
#  #######------------- [33%] [0.01s]None
# None
#  ########------------ [38%] [0.01s]None
#  #########----------- [43%] [0.01s]None
#  ##########---------- [52%] [0.01s]None
#  ###########--------- [57%] [0.01s]None
# None
#  ############-------- [62%] [0.01s]None
#  #############------- [67%] [0.01s]None
#  ##############------ [71%] [0.01s]None
# None
#  ###############----- [76%] [0.01s]None
# None
#  ################---- [81%] [0.01s]None
#  #################--- [86%] [0.01s]None
#  ##################-- [90%] [0.01s]None
#  ###################- [95%] [0.01s]None
#  #################### [100%] [0.01s]
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9571
# M0 - Kappa        : 0.7670
# M0 - Precision: 0.8500
# M0 - Recall: 0.7391
# M0 - F1 score: 0.7907
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9571
# M0 - Kappa        : 0.7670
# M0 - Precision: 0.8500
# M0 - Recall: 0.7391
# M0 - F1 score: 0.7907
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.44444444444444436
# G-Mean: 0.44444444444444436
# Accuracy: 0.6871842709362768
# Recall: 0.9
# Precision: 0.5
# F1 Score: 0.5
# 127.0.0.1 - - [21/Apr/2021 12:00:25] "GET /predict/400 HTTP/1.1" 200 -
#                       excessKurtosisOfTheDMSNRCurve  ...  yPred
# -MYn4hBVef74ZUDNcyf5                       3.735397  ...      1
# -MYn4hBcHLmCKF5epHH1                      12.938800  ...      1
# -MYn4hBdDf4Ma-Ep0T-L                       4.482570  ...      1
# -MYn4hilZLQzUmUmJ4wX                             6.007199  ...       1
# -MYn4hilZLQzUmUmJ4wY                             4.193491  ...       1
# -MYn4hioti7Enk68kJis                             0.956490  ...       1
# -MYn6pbtZ9kQTg7R8FOq                             4.652342  ...       1
# -MYn6pbtZ9kQTg7R8FOr                             1.251158  ...       1
# -MYn6pc1IP3DIKYkGQKm                             2.621427  ...       1
# -MYn6pc3VTaKGyC0LQt5                             1.636346  ...       1
# -MYn6pcC9CS63LFOETj1                             1.389509  ...       1
# -MYn6pwyqBkleBVo6eMJ                             0.285843  ...       1
# -MYn6pwzCYqVk9t0s3FR                             1.601763  ...       1
# -MYn6px9gezaQ2B8bVVU                             1.780299  ...       1
# -MYn6pxHSCMzynll-hQD                             7.461715  ...       0
# -MYn6pxM2HKg72Jyp77P                             8.312472  ...       0
# -MYn6qHDbgapxeEjiudd                             2.694902  ...       1
# -MYn6qHE7kwUZhyuqtdB                             9.598438  ...       0
# -MYn6qHOiVqCR4vrgROe                             2.840049  ...       1
# -MYn6qHPqiaV4i0_bwHx                             0.263897  ...       1
# -MYn6qHgPJ8kJEwEWdtp                             0.029680  ...       1
# -MYn6qciImjQqb7jeFyf                             4.989841  ...       1
# -MYn6qcjUo07YD16pvqP                             0.974168  ...       1
# -MYn6qcmHkXzEZQ5GWu3                             3.136580  ...       1
# -MYn6qcvqTGoRCltCehJ                             0.871271  ...       1
# -MYn6qd2TvaOkt4zSSFg                            10.849845  ...       1
# -MYn6qy8D0Tk8Ca1xdHF                            13.379985  ...       1
# -MYn6qyUX2c8FA01Dcfj                             9.130825  ...       0
# -MYn6qycRQ1gYHAkBfMw                             1.506916  ...       1
# -MYn6qyofkbzl9aCfG9M                             1.304086  ...       1
#
# [38 rows x 10 columns]
#                       Mean of the integrated profile  ...  target_class
# -MYn4hBVef74ZUDNcyf5                       94.773438  ...             1
# -MYn4hBcHLmCKF5epHH1                       64.921875  ...             0
# -MYn4hBdDf4Ma-Ep0T-L                       96.984375  ...             0
# -MYn4hBntX39nvnEGh_c                      110.101562  ...             0
# -MYn4hBpouG6hHmA0ruK                       72.054688  ...             1
#
# [5 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# Time difference: 0:00:00.074586
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Number of learning samples: 38
# 127.0.0.1 - - [21/Apr/2021 12:01:49] "GET /learn-from-all HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]None
#  ####---------------- [19%] [0.00s]None
#  ######-------------- [29%] [0.00s]None
# None
#  ##########---------- [48%] [0.01s]None
# None
#  ##########---------- [52%] [0.01s]None
#  ###########--------- [57%] [0.01s]None
#  ############-------- [62%] [0.01s]None
#  #############------- [67%] [0.01s]None
# None
#  ###############----- [76%] [0.01s]None
#  #################### [100%] [0.02s]
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9714
# M0 - Kappa        : 0.7350
# M0 - Precision: 0.8182
# M0 - Recall: 0.6923
# M0 - F1 score: 0.7500
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9714
# M0 - Kappa        : 0.7350
# M0 - Precision: 0.8182
# M0 - Recall: 0.6923
# M0 - F1 score: 0.7500
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.0
# G-Mean: 0.0
# Accuracy: 0.0
# Recall: 1.0
# Precision: 0.0
# F1 Score: 0.0
# 127.0.0.1 - - [21/Apr/2021 12:02:06] "GET /predict/1000 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  ###----------------- [14%] [0.00s]None
#  #####--------------- [24%] [0.00s]None
#  ######-------------- [29%] [0.00s]None
# None
#  #########----------- [43%] [0.01s]None
#  ##########---------- [48%] [0.01s]None
#  ###########--------- [57%] [0.01s]None
#  ############-------- [62%] [0.01s]None
#  ##############------ [71%] [0.01s]None
#  ###############----- [76%] [0.01s]None
#  ##################-- [90%] [0.01s]None
#  ###################- [95%] [0.01s]None
# None
#  #################### [100%] [0.01s]
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9762
# M0 - Kappa        : 0.8152
# M0 - Precision: 1.0000
# M0 - Recall: 0.7059
# M0 - F1 score: 0.8276
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9762
# M0 - Kappa        : 0.8152
# M0 - Precision: 1.0000
# M0 - Recall: 0.7059
# M0 - F1 score: 0.8276
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.5833333333333333
# G-Mean: 0.5833333333333333
# Accuracy: 0.7071067811865476
# Recall: 0.85
# Precision: 0.5
# F1 Score: 1.0
# 127.0.0.1 - - [21/Apr/2021 12:02:30] "GET /predict/1000 HTTP/1.1" 200 -
#                       excessKurtosisOfTheDMSNRCurve  ...  yPred
# -MYn7DPCTrcXZY_qt229                       6.035006  ...      1
# -MYn7DPDkW5vYxLiEG7b                       6.038939  ...      1
# -MYn7DPE9yQWfJIJE-t7                       2.364657  ...      1
# -MYn7DPE9yQWfJIJE-t8                       8.517613  ...      1
# -MYn7DPGr8IYfYhnBZcx                       2.930925  ...      1
# -MYn7Di7V-EAGRS-eRoo                       9.395289  ...      0
# -MYn7Di7V-EAGRS-eRop                       5.202978  ...      1
# -MYn7Di8AZfybmerypye                       1.589513  ...      1
# -MYn7DiHrYQ_l8xgxVgp                       1.482985  ...      1
# -MYn7DiRmDiIC8Q6fepl                       1.452548  ...      1
# -MYn7E2Fmn-DxPIHNnCm                       2.858017  ...      1
# -MYn7E2MVMxrChqs57VC                       2.580942  ...      1
# -MYn7J8ceX5Xb8P83QD_                       0.956490  ...      1
# -MYn7J8rj7AOk1ybt9PH                       4.193491  ...      1
# -MYn7J95Bblu8WNFvYou                       6.007199  ...      1
# -MYn7J9FbEe3L3it_biM                       1.152047  ...      1
# -MYn7J9bJd3M4qTqfHoE                       5.413000  ...      1
# -MYn7JSoi6dDCq3UZhyN                       9.184136  ...      0
# -MYn7JT6BSY5e7C4I_XZ                       1.965960  ...      1
# -MYn7JT9-4_rvi5n8dn7                       1.062863  ...      1
# -MYn7JTFCFaAlTDgtiUt                       1.672327  ...      1
# -MYn7JTh1GMluWNugOYT                       0.549789  ...      1
# -MYn7JlTTq_QEWiw2nWP                       1.682642  ...      1
# -MYn7JlTTq_QEWiw2nWQ                       1.041178  ...      1
# -MYn7JloEViy9P1PKnqL                       6.309016  ...      1
#
# [25 rows x 10 columns]
#                       Excess kurtosis of the DM-SNR curve  ...  y_pred
# -MYn7DPCTrcXZY_qt229                             6.035006  ...       1
# -MYn7DPDkW5vYxLiEG7b                             6.038939  ...       1
# -MYn7DPE9yQWfJIJE-t7                             2.364657  ...       1
# -MYn7DPE9yQWfJIJE-t8                             8.517613  ...       1
# -MYn7DPGr8IYfYhnBZcx                             2.930925  ...       1
# -MYn7Di7V-EAGRS-eRoo                             9.395289  ...       0
# -MYn7Di7V-EAGRS-eRop                             5.202978  ...       1
# -MYn7Di8AZfybmerypye                             1.589513  ...       1
# -MYn7DiHrYQ_l8xgxVgp                             1.482985  ...       1
# -MYn7DiRmDiIC8Q6fepl                             1.452548  ...       1
# -MYn7E2Fmn-DxPIHNnCm                             2.858017  ...       1
# -MYn7E2MVMxrChqs57VC                             2.580942  ...       1
# -MYn7J8ceX5Xb8P83QD_                             0.956490  ...       1
# -MYn7J8rj7AOk1ybt9PH                             4.193491  ...       1
# -MYn7J95Bblu8WNFvYou                             6.007199  ...       1
# -MYn7J9FbEe3L3it_biM                             1.152047  ...       1
# -MYn7J9bJd3M4qTqfHoE                             5.413000  ...       1
# -MYn7JSoi6dDCq3UZhyN                             9.184136  ...       0
# -MYn7JT6BSY5e7C4I_XZ                             1.965960  ...       1
# -MYn7JT9-4_rvi5n8dn7                             1.062863  ...       1
# -MYn7JTFCFaAlTDgtiUt                             1.672327  ...       1
# -MYn7JTh1GMluWNugOYT                             0.549789  ...       1
# -MYn7JlTTq_QEWiw2nWP                             1.682642  ...       1
# -MYn7JlTTq_QEWiw2nWQ                             1.041178  ...       1
# -MYn7JloEViy9P1PKnqL                             6.309016  ...       1
#
# [25 rows x 10 columns]
#                       Mean of the integrated profile  ...  target_class
# -MYn7DPCTrcXZY_qt229                       57.117188  ...             1
# -MYn7DPDkW5vYxLiEG7b                       57.093750  ...             1
# -MYn7DPE9yQWfJIJE-t7                       56.734375  ...             1
# -MYn7DPE9yQWfJIJE-t8                      101.570312  ...             0
# -MYn7DPGr8IYfYhnBZcx                       82.164062  ...             0
#
# [5 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# Time difference: 0:00:00.056811
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Number of learning samples: 25
# 127.0.0.1 - - [21/Apr/2021 12:03:05] "GET /learn-from-all HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2021 12:03:07] "GET /learn-from-all HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips/flask_api.py", line 21, in learn_from_all
#     log = asips.learn_from_all()
#   File "/Users/venoligamage/Documents/FYP/Implementation/Asips/scikit-multiflow/src/asips/asips_delayed_progressive.py", line 117, in learn_from_all
#     dataframe = pd.DataFrame.from_dict(j, orient='index')
#   File "/Users/venoligamage/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 1297, in from_dict
#     if len(data) > 0:
# TypeError: object of type 'NoneType' has no len()
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  -------------------- [0%] [0.00s]None
#  #------------------- [5%] [0.00s]None
#  ###----------------- [14%] [0.00s]None
#  ######-------------- [29%] [0.00s]None
#  #######------------- [33%] [0.01s]None
#  #########----------- [43%] [0.01s]None
#  ##########---------- [48%] [0.01s]None
# None
# None
#  ##############------ [71%] [0.01s]None
#  ###############----- [76%] [0.02s]None
#  #################--- [86%] [0.02s]None
# None
#  #################### [100%] [0.02s]
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9714
# M0 - Kappa        : 0.7123
# M0 - Precision: 0.6667
# M0 - Recall: 0.8000
# M0 - F1 score: 0.7273
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 210
# Mean performance:
# M0 - Accuracy     : 0.9714
# M0 - Kappa        : 0.7123
# M0 - Precision: 0.6667
# M0 - Recall: 0.8000
# M0 - F1 score: 0.7273
# ...
# -MYn9XHLzpvWRvxmDgo8                       3.739387  ...      1
# -MYn9XHVg1EXgSAjg0VD                       3.907152  ...      1
# -MYn9XHlryjTiImOYdeT                       1.178988  ...      1
# -MYn9XHmM2nrWDcBT9i3                       2.425321  ...      1
# -MYn9XHyvIGxHm5gsNsJ                       3.116141  ...      1
# -MYn9XYNS2hthwpx8GBs                       1.133982  ...      1
# -MYn9XYYG55T4wEYuor4                       8.200373  ...      0
# -MYn9XYkzO4fnGOjUA8L                       1.093189  ...      1
# -MYn9XYkzO4fnGOjUA8M                       1.197500  ...      1
# -MYn9XYtbxfcNB09kbqe                       0.348988  ...      1
# -MYn9Xnf9qlMXxgXluHY                       2.584291  ...      1
# -MYn9XoMDJlkhLAzKEBz                       5.646218  ...      1
# -MYn9Xox-YXvAZxsDGPg                       1.194538  ...      1
# -MYn9XpWSw5x3ZjnGnuc                       1.520492  ...      1
#
# [37 rows x 10 columns]
#                       Excess kurtosis of the DM-SNR curve  ...  y_pred
# -MYn9R4YCvbUMIyWHJjI                            -0.065605  ...       1
# -MYn9R4cRZZe-SJ4AMWr                            10.933958  ...       0
# -MYn9R4ffq0aVet-2HuN                             9.287412  ...       0
# -MYn9R4nECpYN1HbqWRr                             5.962677  ...       0
# -MYn9R9skw0Rhit5CiVZ                             2.486482  ...       1
# -MYn9RLWt1DdnIUDmKCH                             0.527440  ...       1
# -MYn9RM8i3wZDqB8nUhJ                             6.928083  ...       0
# -MYn9RM8i3wZDqB8nUhK                             0.207212  ...       1
# -MYn9RM8i3wZDqB8nUhL                             1.447496  ...       0
# -MYn9RRInvzjxe98hHdR                            -0.132138  ...       1
# -MYn9RcJQ6U_bDAvPP4T                             6.077354  ...       1
# -MYn9RcKIg0oNCW0jLGE                             1.042535  ...       1
# -MYn9RcPDtHFly3FBE7F                             8.558067  ...       0
# -MYn9RcawdNw_492M5pw                             2.695641  ...       1
# -MYn9RhmnhFXqq-QHysy                            -0.043851  ...       0
# -MYn9RtCD4htr9-9gpQA                             8.265378  ...       0
# -MYn9RtTsjeoKN30QQMw                             2.305995  ...       1
# -MYn9RuWr3g7tGtrVxzm                             8.809830  ...       0
# -MYn9X06s11JoMMoh-to                             0.010425  ...       1
# -MYn9X09X67Dx-SBUVSu                            -0.117366  ...       1
# -MYn9X0Jy1nTvZjYj5kF                             0.916619  ...       1
# -MYn9X0QawDZ7DcP-2jE                             0.815807  ...       1
# -MYn9X0_s0lv6tcDqckr                             0.997993  ...       1
# -MYn9XHLzpvWRvxmDgo8                             3.739387  ...       1
# -MYn9XHVg1EXgSAjg0VD                             3.907152  ...       1
# -MYn9XHlryjTiImOYdeT                             1.178988  ...       1
# -MYn9XHmM2nrWDcBT9i3                             2.425321  ...       1
# -MYn9XHyvIGxHm5gsNsJ                             3.116141  ...       1
# -MYn9XYNS2hthwpx8GBs                             1.133982  ...       1
# -MYn9XYYG55T4wEYuor4                             8.200373  ...       0
# -MYn9XYkzO4fnGOjUA8L                             1.093189  ...       1
# -MYn9XYkzO4fnGOjUA8M                             1.197500  ...       1
# -MYn9XYtbxfcNB09kbqe                             0.348988  ...       1
# -MYn9Xnf9qlMXxgXluHY                             2.584291  ...       1
# -MYn9XoMDJlkhLAzKEBz                             5.646218  ...       1
# -MYn9Xox-YXvAZxsDGPg                             1.194538  ...       1
# -MYn9XpWSw5x3ZjnGnuc                             1.520492  ...       1
#
# [37 rows x 10 columns]
#                       Mean of the integrated profile  ...  target_class
# -MYn9R4YCvbUMIyWHJjI                       47.593750  ...             1
# -MYn9R4cRZZe-SJ4AMWr                      109.328125  ...             0
# -MYn9R4ffq0aVet-2HuN                      102.562500  ...             0
# -MYn9R4nECpYN1HbqWRr                      122.578125  ...             0
# -MYn9R9skw0Rhit5CiVZ                       88.773438  ...             0
#
# [5 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# Time difference: 0:00:00.104227
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Number of learning samples: 37
# 127.0.0.1 - - [21/Apr/2021 12:12:28] "GET /learn-from-all HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]None
#  ###----------------- [15%] [0.00s]None
# None
#  #####--------------- [25%] [0.00s]None
#  ######-------------- [30%] [0.00s]None
# None
#  #######------------- [35%] [0.00s]None
# None
#  ########------------ [40%] [0.00s]None
#  ##########---------- [50%] [0.00s]None
#  ###########--------- [55%] [0.00s]None
#  ############-------- [60%] [0.00s]None
#  ##############------ [70%] [0.01s]None
#  ###############----- [75%] [0.01s]None
#  #################--- [85%] [0.01s]None
#  ###################- [95%] [0.01s]None
#  #################### [99%] [0.01s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9600
# M0 - Kappa        : 0.6928
# M0 - Precision: 0.7143
# M0 - Recall: 0.7143
# M0 - F1 score: 0.7143
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9600
# M0 - Kappa        : 0.6928
# M0 - Precision: 0.7143
# M0 - Recall: 0.7143
# M0 - F1 score: 0.7143
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.0
# G-Mean: 0.0
# Accuracy: 0.0
# Recall: 1.0
# Precision: 0.0
# F1 Score: 0.0
# 127.0.0.1 - - [21/Apr/2021 12:12:39] "GET /predict/100 HTTP/1.1" 200 -
# <_MainProcess name='MainProcess' parent=None started>
# Prequential Evaluation
# Evaluating 1 target(s).
# Evaluating...
#  #------------------- [5%] [0.00s]None
# None
#  ##------------------ [10%] [0.00s]None
#  ####---------------- [20%] [0.00s]None
#  ######-------------- [30%] [0.00s]None
#  ########------------ [40%] [0.00s]None
# None
#  ##########---------- [50%] [0.01s]None
# None
# None
#  ###########--------- [55%] [0.01s]None
#  ############-------- [60%] [0.01s]None
#  #############------- [65%] [0.01s]None
#  ###############----- [75%] [0.01s]None
#  #################--- [85%] [0.01s]None
# None
#  ##################-- [90%] [0.01s]None
#  ###################- [95%] [0.01s]None
#  #################### [99%] [0.01s]
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# info:
# <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Processed samples: 100
# Mean performance:
# M0 - Accuracy     : 0.9800
# M0 - Kappa        : 0.8890
# M0 - Precision: 1.0000
# M0 - Recall: 0.8182
# M0 - F1 score: 0.9000
# M0 - Training time (s)  : 0.00
# M0 - Testing time  (s)  : 0.01
# M0 - Total time    (s)  : 0.00
# Kappa: 0.7727272727272725
# G-Mean: 0.7727272727272725
# Accuracy: 0.816496580927726
# Recall: 0.95
# Precision: 0.6666666666666666
# F1 Score: 1.0
# 127.0.0.1 - - [21/Apr/2021 12:12:48] "GET /predict/100 HTTP/1.1" 200 -
#                       excessKurtosisOfTheDMSNRCurve  ...  yPred
# -MYn9dAU6JYOLtXiqT_T                       0.948149  ...      1
# -MYn9dAd-lItyNZIEoXM                       6.782996  ...      0
# -MYn9dAvyBu4ZrpNXa1o                       9.047894  ...      0
# -MYn9dQq8mpO2s3pkkB-                      -0.443610  ...      1
# -MYn9dR-F33doe_v_m_9                       7.743438  ...      0
# -MYn9dR1Qd_Fpdm40sVM                       4.273209  ...      1
# -MYn9dRcVb1i1cso9HcO                       0.239498  ...      1
# -MYn9dRnC3FU6zvvrGOp                       8.645087  ...      1
# -MYn9dgKwwZ_RjcLoYPQ                      11.482574  ...      0
# -MYn9dh422977jqhcoO-                      11.244762  ...      0
# -MYn9dh9TayMexemtyn-                       1.312655  ...      1
# -MYn9di1u2T8jOuTX_h1                       6.860691  ...      0
# -MYn9di4FeAL8wA7x8pZ                       7.702917  ...      1
# -MYn9dwp2saT1lsfvUYy                       9.846663  ...      0
# -MYn9dxSMCD0w9T9LRZe                       3.389532  ...      0
# -MYn9dy5saB3jTxWpEo-                      10.573169  ...      0
# -MYn9f9UciQkUo7cWSLh                       2.451976  ...      1
# -MYn9f9dRLmr5bLi4Lbf                       1.427907  ...      1
# -MYn9f9dRLmr5bLi4Lbg                       3.061046  ...      0
# -MYn9fA-9fqvWMCmYxiT                      -0.688238  ...      0
# -MYn9fA4Dnjaty2V0SDi                      12.787493  ...      0
# -MYn9fRbH_K4bdDYRfS_                       3.844090  ...      1
# -MYn9fRllzqr6DtPwTip                      12.142663  ...      0
# -MYn9fRllzqr6DtPwTiq                       0.928497  ...      1
# -MYn9fRxklFk7p9phnZg                      11.098497  ...      0
# -MYn9fRxklFk7p9phnZh                       4.893210  ...      1
# -MYn9fjME_o_MC1qsDAm                       5.701816  ...      0
# -MYn9fjV2NF2pG93NsWH                       5.244196  ...      1
# -MYn9fjV2NF2pG93NsWI                      10.945448  ...      0
# -MYn9fjo0IJAuDi_caNx                       8.664356  ...      0
# -MYn9fjtysfE8ad7UcJM                       0.427270  ...      1
# -MYn9g1GKE0LfanSBIOl                       2.042711  ...      1
# -MYn9g1iHjNYoP9iO_Om                       8.598820  ...      0
# -MYn9g1jgpb5CqaI3HLH                       0.768770  ...      1
#
# [34 rows x 10 columns]
#                       Excess kurtosis of the DM-SNR curve  ...  y_pred
# -MYn9dAU6JYOLtXiqT_T                             0.948149  ...       1
# -MYn9dAd-lItyNZIEoXM                             6.782996  ...       0
# -MYn9dAvyBu4ZrpNXa1o                             9.047894  ...       0
# -MYn9dQq8mpO2s3pkkB-                            -0.443610  ...       1
# -MYn9dR-F33doe_v_m_9                             7.743438  ...       0
# -MYn9dR1Qd_Fpdm40sVM                             4.273209  ...       1
# -MYn9dRcVb1i1cso9HcO                             0.239498  ...       1
# -MYn9dRnC3FU6zvvrGOp                             8.645087  ...       1
# -MYn9dgKwwZ_RjcLoYPQ                            11.482574  ...       0
# -MYn9dh422977jqhcoO-                            11.244762  ...       0
# -MYn9dh9TayMexemtyn-                             1.312655  ...       1
# -MYn9di1u2T8jOuTX_h1                             6.860691  ...       0
# -MYn9di4FeAL8wA7x8pZ                             7.702917  ...       1
# -MYn9dwp2saT1lsfvUYy                             9.846663  ...       0
# -MYn9dxSMCD0w9T9LRZe                             3.389532  ...       0
# -MYn9dy5saB3jTxWpEo-                            10.573169  ...       0
# -MYn9f9UciQkUo7cWSLh                             2.451976  ...       1
# -MYn9f9dRLmr5bLi4Lbf                             1.427907  ...       1
# -MYn9f9dRLmr5bLi4Lbg                             3.061046  ...       0
# -MYn9fA-9fqvWMCmYxiT                            -0.688238  ...       0
# -MYn9fA4Dnjaty2V0SDi                            12.787493  ...       0
# -MYn9fRbH_K4bdDYRfS_                             3.844090  ...       1
# -MYn9fRllzqr6DtPwTip                            12.142663  ...       0
# -MYn9fRllzqr6DtPwTiq                             0.928497  ...       1
# -MYn9fRxklFk7p9phnZg                            11.098497  ...       0
# -MYn9fRxklFk7p9phnZh                             4.893210  ...       1
# -MYn9fjME_o_MC1qsDAm                             5.701816  ...       0
# -MYn9fjV2NF2pG93NsWH                             5.244196  ...       1
# -MYn9fjV2NF2pG93NsWI                            10.945448  ...       0
# -MYn9fjo0IJAuDi_caNx                             8.664356  ...       0
# -MYn9fjtysfE8ad7UcJM                             0.427270  ...       1
# -MYn9g1GKE0LfanSBIOl                             2.042711  ...       1
# -MYn9g1iHjNYoP9iO_Om                             8.598820  ...       0
# -MYn9g1jgpb5CqaI3HLH                             0.768770  ...       1
#
# [34 rows x 10 columns]
#                       Mean of the integrated profile  ...  target_class
# -MYn9dAU6JYOLtXiqT_T                       49.335938  ...             1
# -MYn9dAd-lItyNZIEoXM                       90.234375  ...             1
# -MYn9dAvyBu4ZrpNXa1o                      112.632812  ...             0
# -MYn9dQq8mpO2s3pkkB-                       22.804688  ...             1
# -MYn9dR-F33doe_v_m_9                      124.171875  ...             0
#
# [5 rows x 9 columns]
# Features:
# ['Mean of the integrated profile', 'Standard deviation of the integrated profile', 'Excess kurtosis of the integrated profile', 'Skewness of the integrated profile', 'Mean of the DM-SNR curve', 'Standard deviation of the DM-SNR curve', 'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve']
# Number of Targets: 1
# Name: ['target_class']
# Target class values: [0, 1]
# Time difference: 0:00:00.109079
# info: <bound method BaseSKMObject.get_info of ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                     leaf_prediction='nba',
#                                     max_byte_size=33554432,
#                                     memory_estimate_period=1000000,
#                                     min_samples_reevaluate=20, nb_threshold=0,
#                                     nominal_attributes=None,
#                                     split_confidence=1e-07,
#                                     split_criterion='gaussian_hellinger',
#                                     stop_mem_management=False,
#                                     tie_threshold=0.05)>
# Number of learning samples: 34
# 127.0.0.1 - - [21/Apr/2021 12:13:04] "GET /learn-from-all HTTP/1.1" 200 -
